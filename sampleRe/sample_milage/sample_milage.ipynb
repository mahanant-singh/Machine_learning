# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("milage.csv")

# %%
df
# Out:
#    Weight  Miles
# 0    3.50     18
# 1    3.69     15
# 2    3.44     18
# 3    3.43     16
# 4    4.34     15
# 5    4.42     14
# 6    2.37     24

# %%
n=df['Weight'].count()

# %%
n
# Out:
# np.int64(7)

# %%
weight_sum=df['Weight'].sum()

# %%
weight_sum
# Out:
# np.float64(25.19)

# %%
Miles_sum=df['Miles'].sum()

# %%
Miles_sum
# Out:
# np.int64(120)

# %%
weight_sum_square=(df['Weight']*df['Miles']).sum()

# %%
weight_sum_square
# Out:
# np.float64(419.01)

# %%
weight_sum_square=(df['Weight']*df['Weight']).sum()

# %%
miles_sum_square=(df['Miles']*df['Miles']).sum()

# %%
miles_sum_square
# Out:
# np.int64(2126)

# %%
weight_sum_square
# Out:
# np.float64(93.4535)

# %%
sum_weight_miles=(df['Weight']*df['Weight']).sum()

# %%
sum_weight_miles
# Out:
# np.float64(93.4535)

# %%
slope=(n*sum_weight_miles-(Miles_sum*weight_sum))/(n*weight_sum_square-Miles_sum*Miles_sum)

# %%
slope
# Out:
# np.float64(0.1723159878611874)

# %%
intercept=(Miles_sum*weight_sum_square-Miles_sum*sum_weight_miles)/(n*miles_sum_square-Miles_sum*Miles_sum)

# %%
intercept
# Out:
# np.float64(0.0)
