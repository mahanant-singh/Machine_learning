# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("placement.csv")

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['package'])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('cgpa')
plt.ylabel('Package(in lakhs)')
# Out:
# Text(0, 0.5, 'Package(in lakhs)')

# %%
X=df.iloc[:,0:1]

# %%
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
Y=df.iloc[:,-1]

# %%
Y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.2)

# %%
X_train
# Out:
#      cgpa
# 55   8.20
# 18   6.94
# 34   7.34
# 191  7.28
# 195  6.93
# ..    ...
# 57   6.60
# 30   7.36
# 48   8.63
# 162  5.53
# 184  7.88
#
# [160 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr =LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color="red")
plt.xlabel('cgpa')
plt.ylabel('Package(in lakhs)')
# Out:
# Text(0, 0.5, 'Package(in lakhs)')

# %%
c=lr.coef_

# %%
c=lr.intercept_

# %%
result=lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# c:\Users\singh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([2.33741454])

# %%
import pickle

# %%
pickle.dump(result,open("placementpred1.pkl","wb"))

# %%
result.predict(pd.DataFrame([9]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 result.predict(pd.DataFrame([9]))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'predict'
